# %% [markdown]
# <a href="https://colab.research.google.com/github/devmofizur/Python/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([5,4,9,10])
x.ndim
# Out:
# 1

# %%
x = np.array([[5,4],[9,10]], dtype = np.int32)
y = np.array([[1,2],[74,4]], dtype= np.float64)

x.ndim
# Out:
# 2

# %%
x.itemsize
# Out:
# 4

# %%
x
# Out:
# array([[ 5,  4],
#        [ 9, 10]], dtype=int32)

# %%
x[1,0] = 4

# %%
x
# Out:
# array([[ 5,  4],
#        [ 4, 10]], dtype=int32)

# %%
x.dtype
# Out:
# dtype('int32')

# %%
y.dtype
# Out:
# dtype('float64')

# %%
z = (x+y)

# %%
x.nbytes
# Out:
# 16

# %%
y.nbytes
# Out:
# 32

# %%
z.nbytes
# Out:
# 32

# %%
z.shape
# Out:
# (2, 2)

# %%
np.sort(z)
# Out:
# array([[ 6.,  6.],
#        [14., 78.]])

# %%
np.sort(z, axis =None) # flatten array
# Out:
# array([ 6.,  6., 14., 78.])

# %%
z
# Out:
# array([[ 6.,  6.],
#        [78., 14.]])

# %%
z.flatten() # New array with flatten()
# Out:
# array([ 6.,  6., 78., 14.])

# %%
z # original array is not flat
# Out:
# array([[ 6.,  6.],
#        [78., 14.]])

# %%
z.ravel() # a flat view of array z
# Out:
# array([ 6.,  6., 78., 14.])

# %%
z
# Out:
# array([[ 6.,  6.],
#        [78., 14.]])

# %%
z.reshape(4,1)
# Out:
# array([[ 6.],
#        [ 6.],
#        [78.],
#        [14.]])

# %%
z
# Out:
# array([[ 6.,  6.],
#        [78., 14.]])

# %%
z.min()
# Out:
# np.float64(6.0)

# %%
z.max()
# Out:
# np.float64(78.0)

# %%
z.sum(axis=1) # a1+a2 , b1+b2(co-ordinal values)
# Out:
# array([12., 92.])

# %%
z.sum(axis=0) # a1+b1 , a2+b2 (co-ordinal values)
# Out:
# array([84., 20.])

# %%
z
# Out:
# array([[ 6.,  6.],
#        [78., 14.]])

# %%
for row in z:
  print("row :-> ",row)
# Out:
# row :->  [6. 6.]
# row :->  [78. 14.]

# %%
np.sqrt(z)
# Out:
# array([[2.44948974, 2.44948974],
#        [8.83176087, 3.74165739]])

# %%
np.mean(z)
# Out:
# np.float64(26.0)

# %%
np.std(z) #standard deviation
# Out:
# np.float64(30.199337741083)
